# %%
import os

print(os.getcwd())
# Out:
# C:\Users\palch\OneDrive\Documents\OneDrive\Desktop\Customer_Shopping_Behavior_Analysis\notebooks

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\palch\Downloads\customer_shopping_behavior_dataset.csv')

df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   58    Male          Dress  Clothing                     51
# 1            2   56    Male          Heels  Footwear                     73
# 2            3   66  Female        Sweater  Clothing                     68
# 3            4   36  Female        Sandals  Footwear                     25
# 4            5   41  Female          Boots  Footwear                     29
#
#        Location Size   Color  Season  Review Rating Subscription Status  \
# 0     Louisiana    M   White  Winter            4.0                 Yes
# 1     Louisiana   XL    Gold  Winter            4.4                 Yes
# 2  Rhode Island    L   Green  Summer            4.5                  No
# 3       Georgia    M  Violet  Winter            4.6                 Yes
# 4       Florida    M   Olive  Spring            3.7                  No
#
#     Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             1000 non-null   int64
#  1   Age                     1000 non-null   int64
#  2   Gender                  1000 non-null   object
#  3   Item Purchased          1000 non-null   object
#  4   Category                1000 non-null   object
#  5   Purchase Amount (USD)   1000 non-null   int64
#  6   Location                1000 non-null   object
#  7   Size                    1000 non-null   object
#  8   Color                   1000 non-null   object
#  9   Season                  1000 non-null   object
#  10  Review Rating           1000 non-null   float64
#  11  Subscription Status     1000 non-null   object
#  12  Shipping Type           1000 non-null   object
#  13  Discount Applied        1000 non-null   object
# ...

# %%
df.describe(include='all')
# Out:
#         Customer ID          Age  Gender Item Purchased  Category  \
# count   1000.000000  1000.000000    1000           1000      1000
# unique          NaN          NaN       2             23         4
# top             NaN          NaN  Female           Coat  Clothing
# freq            NaN          NaN     522            101       273
# mean     500.500000    44.420000     NaN            NaN       NaN
# std      288.819436    15.050253     NaN            NaN       NaN
# min        1.000000    18.000000     NaN            NaN       NaN
# 25%      250.750000    32.000000     NaN            NaN       NaN
# 50%      500.500000    44.000000     NaN            NaN       NaN
# 75%      750.250000    57.000000     NaN            NaN       NaN
# max     1000.000000    70.000000     NaN            NaN       NaN
#
#         Purchase Amount (USD)    Location  Size Color Season  Review Rating  \
# count             1000.000000        1000  1000  1000   1000    1000.000000
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
df = df.rename(columns={ 'purchase_amount_(usd)': 'purchase_amount'})

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
#create a column age_group 
labels = ['Young Adult','Adult','middle-aged','senior']
df['age_group'] = pd.qcut(df['age'], q=4, labels = labels)

# %%
df[['age','age_group']].head(10)
# Out:
#    age    age_group
# 0   58       senior
# 1   56  middle-aged
# 2   66       senior
# 3   36        Adult
# 4   41        Adult
# 5   32  Young Adult
# 6   65       senior
# 7   45  middle-aged
# 8   47  middle-aged
# 9   19  Young Adult

# %%
# purchase_frequency_days

frequency_mapping = {
    'Fortnightly': 14,
    'Weekly': 7,
    'Monthly': 30,
    'Quarterly': 90,
    'Bi-Weekly': 14,
    'Annually': 365,
    'Every 3 Months': 90
}

df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['purchase_frequency_days', 'frequency_of_purchases']].head(10)
# Out:
#    purchase_frequency_days frequency_of_purchases
# 0                      365               Annually
# 1                       14            Fortnightly
# 2                      365               Annually
# 3                       14            Fortnightly
# 4                        7                 Weekly
# 5                       14            Fortnightly
# 6                       14              Bi-Weekly
# 7                       14            Fortnightly
# 8                       90              Quarterly
# 9                       90              Quarterly

# %%
df[['discount_applied','promo_code_used']].head(10)
# Out:
#   discount_applied promo_code_used
# 0              Yes             Yes
# 1               No              No
# 2              Yes             Yes
# 3               No              No
# 4              Yes             Yes
# 5               No             Yes
# 6              Yes             Yes
# 7               No             Yes
# 8              Yes             Yes
# 9              Yes             Yes

# %%
(df['discount_applied'] == df['promo_code_used']).all()
# Out:
# np.False_

# %%
# !pip install pymysql sqlalchemy

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

username = "root"
password = "swapna@mysql1"
host = "localhost"
port = "3306"
database = "shopping_analysis"

engine = create_engine(
    f"mysql+pymysql://{root}:{quote_plus(swapna@mysql1)}@{localhost}:{3306}/{shopping_analysis}"
)

table_name = "my_table"

df.to_sql(
    table_name,
    engine,
    if_exists="replace",
    index=False
)

df_read = pd.read_sql(
    "SELECT * FROM my_table LIMIT 5;",
    engine
)

df_read
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 11
#       7 port = "3306"
#       8 database = "shopping_analysis"
#      10 engine = create_engine(
# ---> 11     f"mysql+pymysql://{root}:{quote_plus(swapna@mysql1)}@{localhost}:{3306}/{shopping_analysis}"
#      12 )
#      14 table_name = "my_table"
#      16 df.to_sql(
#      17     table_name,
#      18     engine,
#      19     if_exists="replace",
#      20     index=False
#      21 )
#
# NameError: name 'root' is not defined

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

username = "root"
password = "swapna@mysql1"
host = "localhost"
port = "3306"
database = "shopping_analysis"

engine = create_engine(
    f"mysql+pymysql://{username}:{quote_plus(password)}@{host}:{port}/{database}"
)

table_name = "my_table"

df.to_sql(
    table_name,
    engine,
    if_exists="replace",
    index=False
)

df_read = pd.read_sql(
    "SELECT * FROM my_table LIMIT 5;",
    engine
)

df_read
# Out:
#    customer_id  age  gender item_purchased  category  purchase_amount  \
# 0            1   58    Male          Dress  Clothing               51
# 1            2   56    Male          Heels  Footwear               73
# 2            3   66  Female        Sweater  Clothing               68
# 3            4   36  Female        Sandals  Footwear               25
# 4            5   41  Female          Boots  Footwear               29
#
#        location size   color  season  review_rating subscription_status  \
# 0     Louisiana    M   White  Winter            4.0                 Yes
# 1     Louisiana   XL    Gold  Winter            4.4                 Yes
# 2  Rhode Island    L   Green  Summer            4.5                  No
# 3       Georgia    M  Violet  Winter            4.6                 Yes
# 4       Florida    M   Olive  Spring            3.7                  No
#
#     shipping_type discount_applied promo_code_used  previous_purchases  \
# ...

# %%
df.to_sql(
    "my_table",
    engine,
    if_exists="replace",
    index=False
)
# Out:
# 1000
